# %%
import numpy as np
import numpy.matlib
import matplotlib.pyplot as plt
from pytictoc import TicToc
# 
D = 5
#
z = np.random.randn(D)
# 
Nset = np.array([10, 100, 1000, 10000, 100000, 1000000])

t = TicToc()
t1 = []
t2 = []

for N in Nset:
    X = np.random.rand(N, D)
    t.tic()
    dist1 = np.zeros(N)
    for n in range(0, N):
        dist1[n] = np.sqrt(np.sum((X[n,:]-z)**2))
    t.toc()
    t1 = np.append(t1, t.tocvalue())
    t.tic()
    Z = np.matlib.repmat(z.reshape((1,D)), N, 1)
    dist1 = np.sum((X-Z)**2, axis = 1)
    t.toc()
    t2 = np.append(t2, t.tocvalue())

plt.figure(figsize = (5, 5))
plt.plot(Nset, 1e3*t1)
plt.plot(Nset, 1e3*t2)
plt.xlabel("number of samples")
plt.ylabel("computation time [ms]")
plt.xscale("log")
plt.yscale("log")
plt.legend({'blank1','blank2'})
plt.savefig('code.eps')
# Out:
# Elapsed time is 0.001230 seconds.
# Elapsed time is 0.003408 seconds.
# Elapsed time is 0.001757 seconds.
# Elapsed time is 0.000077 seconds.
# Elapsed time is 0.012871 seconds.
# Elapsed time is 0.000163 seconds.
# Elapsed time is 0.097515 seconds.
# Elapsed time is 0.000904 seconds.
# Elapsed time is 0.763188 seconds.
# Elapsed time is 0.006103 seconds.
# Elapsed time is 7.828410 seconds.
# Elapsed time is 0.086931 seconds.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
